# %%
# !pip install -e ..
# Out:
# Obtaining file:///Users/shamil/Documents/curs/reps/aurora-data-loader
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: xarray>=2023.12.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from aurora-data-loader==0.1.0) (2025.12.0)
# Requirement already satisfied: zarr>=2.16.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from aurora-data-loader==0.1.0) (3.1.5)
# Requirement already satisfied: gcsfs>=2023.12.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from aurora-data-loader==0.1.0) (2025.12.0)
# Requirement already satisfied: fsspec>=2023.10.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from aurora-data-loader==0.1.0) (2025.12.0)
# Requirement already satisfied: numpy>=1.24.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from aurora-data-loader==0.1.0) (2.4.0)
# Requirement already satisfied: netcdf4>=1.6.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from aurora-data-loader==0.1.0) (1.7.3)
# Requirement already satisfied: torch>=2.0.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from aurora-data-loader==0.1.0) (2.9.1)
# Requirement already satisfied: scipy>=1.10.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from aurora-data-loader==0.1.0) (1.16.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (3.13.2)
# Requirement already satisfied: decorator>4.1.2 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (5.2.1)
# Requirement already satisfied: google-auth>=1.2 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (2.41.1)
# Requirement already satisfied: google-auth-oauthlib in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (1.2.3)
# Requirement already satisfied: google-cloud-storage in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (3.7.0)
# Requirement already satisfied: google-cloud-storage-control in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (1.8.0)
# Requirement already satisfied: requests in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (2.32.5)
# Requirement already satisfied: cftime in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from netcdf4>=1.6.0->aurora-data-loader==0.1.0) (1.6.5)
# Requirement already satisfied: certifi in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from netcdf4>=1.6.0->aurora-data-loader==0.1.0) (2025.11.12)
# Requirement already satisfied: filelock in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from torch>=2.0.0->aurora-data-loader==0.1.0) (3.20.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from torch>=2.0.0->aurora-data-loader==0.1.0) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from torch>=2.0.0->aurora-data-loader==0.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from torch>=2.0.0->aurora-data-loader==0.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from torch>=2.0.0->aurora-data-loader==0.1.0) (3.1.6)
# Requirement already satisfied: packaging>=24.1 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from xarray>=2023.12.0->aurora-data-loader==0.1.0) (25.0)
# Requirement already satisfied: pandas>=2.2 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from xarray>=2023.12.0->aurora-data-loader==0.1.0) (2.3.3)
# Requirement already satisfied: donfig>=0.8 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from zarr>=2.16.0->aurora-data-loader==0.1.0) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from zarr>=2.16.0->aurora-data-loader==0.1.0) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from zarr>=2.16.0->aurora-data-loader==0.1.0) (0.16.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (1.22.0)
# Requirement already satisfied: pyyaml in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from donfig>=0.8->zarr>=2.16.0->aurora-data-loader==0.1.0) (6.0.3)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from google-auth>=1.2->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from google-auth>=1.2->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from google-auth>=1.2->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (4.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from pandas>=2.2->xarray>=2023.12.0->aurora-data-loader==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from pandas>=2.2->xarray>=2023.12.0->aurora-data-loader==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from pandas>=2.2->xarray>=2023.12.0->aurora-data-loader==0.1.0) (2025.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=2.0.0->aurora-data-loader==0.1.0) (1.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from google-auth-oauthlib->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (2.0.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from google-cloud-storage->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (2.28.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from google-cloud-storage->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from google-cloud-storage->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (2.8.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from requests->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from requests->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from requests->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (2.6.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from google-cloud-storage-control->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (1.76.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from google-cloud-storage-control->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (1.27.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from google-cloud-storage-control->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (6.33.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from google-cloud-storage-control->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (0.14.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from jinja2->torch>=2.0.0->aurora-data-loader==0.1.0) (3.0.3)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (1.72.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (1.76.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (0.6.1)
# Requirement already satisfied: six>=1.5 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.2->xarray>=2023.12.0->aurora-data-loader==0.1.0) (1.17.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/shamil/Documents/curs/reps/aurora-data-loader/venv/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs>=2023.12.0->aurora-data-loader==0.1.0) (3.3.1)
# Building wheels for collected packages: aurora-data-loader
#   Building editable for aurora-data-loader (pyproject.toml) ... done
#   Created wheel for aurora-data-loader: filename=aurora_data_loader-0.1.0-0.editable-py3-none-any.whl size=3024 sha256=f2b6d37ff2ca93628a44ea13ffd094d8a7cf60975fd06c9b9d4bc412c9e16ee1
#   Stored in directory: /private/var/folders/1f/dcfygpyd7vj5j4y2m5r8cj5m0000gn/T/pip-ephem-wheel-cache-1lgk_2_t/wheels/52/31/9c/e55e59aa12549fc65d47a8f27216a50daf8ca85898799c56f0
# Successfully built aurora-data-loader
# Installing collected packages: aurora-data-loader
#   Attempting uninstall: aurora-data-loader
#     Found existing installation: aurora-data-loader 0.1.0
#     Uninstalling aurora-data-loader-0.1.0:
#       Successfully uninstalled aurora-data-loader-0.1.0
# Successfully installed aurora-data-loader-0.1.0
#
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
from src.dataloader.dataloader import create_dataloader

# %%
atmos_vars = [
                "temperature",
                "u_component_of_wind",
                "v_component_of_wind",
                "specific_humidity",
                "geopotential",
            ]
surface_vars = [
                "2m_temperature",
                "10m_u_component_of_wind",
                "10m_v_component_of_wind",
                "mean_sea_level_pressure",
            ]
static_vars = ["geopotential_at_surface", "land_sea_mask", "soil_type"]
dataloader = create_dataloader(atmos_vars=atmos_vars, 
                               surface_vars=surface_vars,
                               static_vars=surface_vars,
                               start_date='2021-05-03',
                               end_date='2021-10-05',
                               batch_size=3)

# %%
batch_saved = None
for batch in dataloader:
    batch_saved = batch
    break
# Out:
# /Users/shamil/jupyter_env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
batch_saved.atmos_vars
