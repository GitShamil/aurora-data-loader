# %%
# !pip install -e ..
# Out:
# Obtaining file:///Users/shamil/Documents/curs/reps/aurora-data-loader
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for aurora-data-loader (pyproject.toml) ... done
#   Created wheel for aurora-data-loader: filename=aurora_data_loader-0.1.0-0.editable-py3-none-any.whl size=3024 sha256=49a230cad9153bd37ca961e11b62c43e1ba9d6d5fd7d7b5df3afd25a78adc790
#   Stored in directory: /private/var/folders/1f/dcfygpyd7vj5j4y2m5r8cj5m0000gn/T/pip-ephem-wheel-cache-tb_dzhfb/wheels/52/31/9c/e55e59aa12549fc65d47a8f27216a50daf8ca85898799c56f0
# Successfully built aurora-data-loader
# ...
#   Attempting uninstall: aurora-data-loader
#     Found existing installation: aurora-data-loader 0.1.0
#     Uninstalling aurora-data-loader-0.1.0:
#       Successfully uninstalled aurora-data-loader-0.1.0
# ...
#
# ...

# %%
from src.dataloader import create_dataloader

# %%
dataloader = create_dataloader(start_date='2021-05-03', end_date='2021-10-05', batch_size=3)

# %%
batch_saved = None
for batch in dataloader:
    batch_saved = batch
    break
# Out:
# /Users/shamil/jupyter_env/lib/python3.11/site-packages/torch/utils/data/dataloader.py:692: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   warnings.warn(warn_msg)

# %%
batch_saved.atmos_vars
# Out:
# {'t': tensor([[[[[267.1061, 267.1061, 267.1061,  ..., 267.1061, 267.1061,
#              267.1061],
#             [267.0554, 267.0554, 267.0541,  ..., 267.0605, 267.0580,
#              267.0580],
#             [266.9159, 266.9109, 266.9070,  ..., 266.9248, 266.9210,
#              266.9172],
#             ...,
#             [249.4019, 249.4070, 249.4121,  ..., 249.3854, 249.3918,
#              249.3956],
#             [249.1597, 249.1648, 249.1699,  ..., 249.1432, 249.1496,
#              249.1534],
#             [248.2645, 248.2645, 248.2645,  ..., 248.2645, 248.2645,
#              248.2645]]]],
#
#
#
#          [[[[273.6387, 273.6387, 273.6387,  ..., 273.6387, 273.6387,
#              273.6387],
#             [273.7242, 273.7242, 273.7242,  ..., 273.7256, 273.7256,
#              273.7242],
#             [273.7783, 273.7769, 273.7769,  ..., 273.7783, 273.7783,
#              273.7783],
#             ...,
#             [241.9000, 241.9071, 241.9128,  ..., 241.8829, 241.8886,
# ...
